# %%
import random as rd
import numpy as np
import pandas as pd
import matplotlib as mat
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.__version__
# Out:
# '2.3.1'

# %%
pd.__version__
# Out:
# '2.3.0'

# %%
mat.__version__
# Out:
# '3.10.3'

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
#Carregando um dos datasets que vem com o Seaborn
dados = sns.load_dataset('tips')

# %%
dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# O método joinplot cria plot de 2 variáveis com gráficos bivariados e univariados
sns.jointplot(data=dados,x='total_bill',y='tip',kind='reg')
plt.show()

# %%
# O método lmplot() cria plot com dados e modelos de regressão
sns.lmplot(data=dados,x='total_bill',y='tip',col='smoker')
plt.show()

# %%
# Construindo um dataframe com Pandas
df = pd.DataFrame()

# %%
# Alimentando o Dataframe com valores aleatórios
df['Idade'] = rd.sample(range(20,100),30)
df['Massa'] = rd.sample(range(55,150),30)

# %%
df.shape
# Out:
# (30, 2)

# %%
df.head()
# Out:
#    Idade  Massa
# 0     74    109
# 1     79     83
# 2     47    132
# 3     57     60
# 4     98     76

# %%
# lmplot
sns.lmplot(data=df,x='Idade',y='Massa')
plt.show()

# %%
#kdeplot
sns.kdeplot(df.Idade)
# Out:
# <Axes: xlabel='Idade', ylabel='Density'>

# %%
sns.kdeplot(df.Massa)
# Out:
# <Axes: xlabel='Massa', ylabel='Density'>

# %%
#distplot
sns.distplot(df.Massa)
plt.show()
# Out:
# C:\Users\Robert Fernandes\AppData\Local\Temp\ipykernel_18932\1697991090.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Massa)

# %%
#displot
sns.displot(df.Massa)
plt.show()

# %%
# Histograma
plt.hist(df.Idade,alpha=0.3)
sns.rugplot(df.Idade)
plt.show()

# %%
#boxplot
sns.boxplot(df.Idade,color='m')
plt.show()

# %%
#boxplot
sns.boxplot(df.Massa,color='y')
plt.show()

# %%
# Violin Plot
sns.violinplot(df.Idade,color='c')
plt.show()

# %%
# Violin Plot
sns.violinplot(df.Massa,color='g')
# Out:
# <Axes: ylabel='Massa'>

# %%
#Clustermap
sns.clustermap(df)
plt.show()

# %%
#Clustermap
sns.clustermap(df.T)
plt.show()

# %% [markdown]
# # Usando Matplotlib, Seaborn, NumPy e Pandas na Criação de Gráfico Estatístico

# %%
# Valores randômicos
np.random.seed(42)
n = 1000
pct_smokers = 0.2

# Variáveis
flag_fumante = np.random.rand(n) < pct_smokers
idade = np.random.normal(40, 10, n)
altura = np.random.normal(170, 10, n)
peso = np.random.normal(70, 10, n)

# Dataframe
dados = pd.DataFrame({'altura': altura, 'peso': peso, 'flag_fumante': flag_fumante})

# Cria os dados para a variável flag_fumante
dados['flag_fumante'] = dados['flag_fumante'].map({True: 'Fumante', False: 'Não Fumante'})

# %%
dados.shape
# Out:
# (1000, 3)

# %%
dados.head()
# Out:
#        altura       peso flag_fumante
# 0  155.936825  78.745171  Não Fumante
# 1  169.168944  63.502348  Não Fumante
# 2  154.952796  57.967991  Não Fumante
# 3  177.600560  59.579556  Não Fumante
# 4  170.824398  65.127971      Fumante

# %%
#Syle
sns.set(style='ticks')

#lmplot
sns.lmplot(x='altura',
           y='peso',
           data=dados,
           hue='flag_fumante',
           palette=['tab:blue','tab:orange'],
           height=7)
#Labels e título
plt.xlabel('Altura (cm)')
plt.ylabel('Massa (kg)')
plt.title('Relação entre altura e massa de Fumantes e Não Fumantes')

#Remove bordas
sns.despine()

#show
plt.show()
